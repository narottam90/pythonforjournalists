# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Clean-data-with-Python-Pandas" data-toc-modified-id="Clean-data-with-Python-Pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Clean data with Python Pandas</a></span><ul class="toc-item"><li><span><a href="#About-Jupyter-Notebooks-and-Pandas" data-toc-modified-id="About-Jupyter-Notebooks-and-Pandas-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>About Jupyter Notebooks and Pandas</a></span></li></ul></li><li><span><a href="#Getting-started" data-toc-modified-id="Getting-started-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Getting started</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-data" data-toc-modified-id="Import-data-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Import data</a></span></li></ul></li><li><span><a href="#Explore-data" data-toc-modified-id="Explore-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Explore data</a></span></li></ul></li><li><span><a href="#Clean-data" data-toc-modified-id="Clean-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Clean data</a></span><ul class="toc-item"><li><span><a href="#Cleaning-strings" data-toc-modified-id="Cleaning-strings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Cleaning strings</a></span></li><li><span><a href="#Delete-columns" data-toc-modified-id="Delete-columns-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Delete columns</a></span></li><li><span><a href="#Renaming-columns" data-toc-modified-id="Renaming-columns-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Renaming columns</a></span></li><li><span><a href="#Clean-up-column-names" data-toc-modified-id="Clean-up-column-names-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Clean up column names</a></span></li><li><span><a href="#Cleaning-dates" data-toc-modified-id="Cleaning-dates-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Cleaning dates</a></span></li><li><span><a href="#Adding-columns-with-year-and-month" data-toc-modified-id="Adding-columns-with-year-and-month-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Adding columns with year and month</a></span></li></ul></li><li><span><a href="#Removing-columns" data-toc-modified-id="Removing-columns-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Removing columns</a></span><ul class="toc-item"><li><span><a href="#Save-your-data" data-toc-modified-id="Save-your-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Save your data</a></span></li></ul></li></ul></div>

# %% [markdown]
#   # Clean data with Python Pandas

# %% [markdown]
# Welcome to this Jupyter Notebook!
#
# Today you'll learn how to import a CSV file into a Jupyter Notebook, and how to clean up messy data. This notebook is part of the course Python for Journalists at [Learno.net](learno.net). The data used originally comes from [the Electoral Commission website](http://search.electoralcommission.org.uk/Search?currentPage=1&rows=10&sort=AcceptedDate&order=desc&tab=1&open=filter&et=pp&isIrishSourceYes=false&isIrishSourceNo=false&date=Reported&from=&to=&quarters=2018Q12&rptPd=3617&prePoll=false&postPoll=false&donorStatus=individual&donorStatus=tradeunion&donorStatus=company&donorStatus=unincorporatedassociation&donorStatus=publicfund&donorStatus=other&donorStatus=registeredpoliticalparty&donorStatus=friendlysociety&donorStatus=trust&donorStatus=limitedliabilitypartnership&donorStatus=impermissibledonor&donorStatus=na&donorStatus=unidentifiabledonor&donorStatus=buildingsociety&register=ni&register=gb&optCols=Register&optCols=IsIrishSource&optCols=ReportingPeriodName), but is edited for training purposes. The edited dataset is available on the Learno website.
#
# Remember: before you start working with data, make sure to create a copy of the original dataset.

# %% [markdown]
# ## About Jupyter Notebooks and Pandas

# %% [markdown]
# Right now you're looking at a Jupyter Notebook: an interactive, browser based programming environment. You can use these notebooks to program in R, Julia or Python - as you'll be doing later on. Read more about Jupyter Notebook in the [Jupyter Notebook Quick Start Guide](https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html).
#
# To clean up our data, we'll be using Python and Pandas. Pandas is an open-source Python library - basically an extra toolkit to go with Python - that is designed for data analysis. Pandas is flexible, easy to use and has lots of useful functions built right in. Read more about Pandas and its features in [the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).
#
# **Notebook shortcuts**
#
# Within Jupyter Notebooks, there are some shortcuts you can use. If you'll be using more notebooks for your data analysis in the future, you'll remember these shortcuts soon enough. :)
#
# * `esc` will take you into command mode
# * `a` will insert cell above
# * `b` will insert cell below
# * `shift then tab` will show you the documentation for your code
# * `shift and enter` will run your cell
# * ` d d` will delete a cell
#
# **Pandas dictionary**
#
# * **dataframe**: dataframe is Pandas speak for a table with a labeled y-axis, also known as an index. (The index usually starts at 0.)
# * **series**: a series is a list, a series can be made of a single column within a dataframe.
#
# Before we dive in, a little more about Jupyter Notebooks. Every notebooks is made out of cells. A cell can either contain Markdown text - like this one - or code. In the latter you can execute your code. To see what that means, type the following command in the next cell `print("hello world")`.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# OK, if you're good to go, let dive in...

# %% [markdown]
# # Getting started
#
# Before we can work on our data, we need to import all libraries we'll need. In this case, we need to import the Pandas library. You can do that by typing in `import pandas as pd`.

# %%
import pandas as pd

# %% [markdown]
# `as pd` means that when you'll be writing code you can refer to the library by writing `pd` instead of `pandas`. It's just a little bit shorter and therefore more efficient - something programmers like a lot.

# %% [markdown]
# ### Import data

# %% [markdown]
# For this course, we'll be using data on donations done to British political parties. The data was originally downloaded from [the Electoral Commission website](http://search.electoralcommission.org.uk/Search?currentPage=1&rows=10&sort=AcceptedDate&order=desc&tab=1&open=filter&et=pp&isIrishSourceYes=false&isIrishSourceNo=false&date=Reported&from=&to=&quarters=2018Q12&rptPd=3617&prePoll=false&postPoll=false&donorStatus=individual&donorStatus=tradeunion&donorStatus=company&donorStatus=unincorporatedassociation&donorStatus=publicfund&donorStatus=other&donorStatus=registeredpoliticalparty&donorStatus=friendlysociety&donorStatus=trust&donorStatus=limitedliabilitypartnership&donorStatus=impermissibledonor&donorStatus=na&donorStatus=unidentifiabledonor&donorStatus=buildingsociety&register=ni&register=gb&optCols=Register&optCols=IsIrishSource&optCols=ReportingPeriodName).
#
# We are going to create a dataframe by importing a CSV with our data. Data can be imported using the following code: `df = pd.read_csv('filename.csv')`.

# %%
database = pd.read_csv('results.csv')

# %% [markdown]
# Sometimes you'll have a CSV file that doesn't use comma's to seperate values, but uses semi-colons or something else entirely. To import such a dataset change the code into:
# `df = pd.read_csv('filename.csv', delimiter=";")`.

# %% [markdown]
# ## Explore data

# %% [markdown]
# When importing our data, we save the CSV file inside a dataframe that is called `df`. We can now explore the data by refering to the dataframe as `df`. It's important to 'get to know' your data, so you know what you're working with.
#
# Use `df.head(10)` to look at the first ten rows of the data:

# %%
database.sample(10)
# Out:
#         ECRef              RegulatedEntityName RegulatedEntityType  \
# 291  C0376428  Conservative and Unionist Party     Political Party
# 83   C0364239                Liberal Democrats     Political Party
# 113  C0393886                     Labour Party     Political Party
# 81   C0364316    Scottish National Party (SNP)     Political Party
# 73   C0364211                Liberal Democrats     Political Party
# 175  C0364243                Liberal Democrats     Political Party
# 204  C0364093                Liberal Democrats     Political Party
# 239  C0376405  Conservative and Unionist Party     Political Party
# 18   C0394115                Liberal Democrats     Political Party
# 115  C0364216                Liberal Democrats     Political Party
#
#           Value AcceptedDate                AccountingUnitName  \
# 291   £2,500.00   27/03/2017                            Havant
# 83    £2,024.62   31/12/2017                     Milton Keynes
# 113   £4,957.00   21/12/2017                     Central Party
# 81    £3,160.00   31/12/2017  Glasgow Shettleston Constituency
# 73    £1,800.00   31/12/2017                           Watford
# 175   £1,568.08   30/11/2017                       Mole Valley
# 204   £5,080.00   15/11/2017                     Central Party
# 239  £10,000.00   18/10/2017                      Surrey Heath
# 18    £2,200.00   31/12/2017                     Central Party
# 115  £22,466.38   21/12/2017                     Central Party
#
#                   DonorName  AccountingUnitsAsCentralParty  IsSponsorship  \
# 291          Mr Jeremy Hand                          False          False
# 83        Mrs Isobel McCall                          False          False
# 113     Mr Stephen Kinsella                          False          False
# 81            Mr John Mason                          False          False
# 73       Ms Jane Mactaggart                          False          False
# 175        Mrs Hazel Watson                          False          False
# 204      Mr Anthony  Harris                          False          False
# 239      Lord Philip Harris                          False          False
# 18   Lord Tim Clement-Jones                          False          False
# 115       Mr Robert Chicken                          False          False
#
#     DonorStatus  ...  IsReportedPrePoll  ReportingPeriodName  IsBequest  \
# 291  Individual  ...                NaN              Q4 2017      False
# 83   Individual  ...                NaN              Q4 2017      False
# 113  Individual  ...                NaN              Q4 2017      False
# 81   Individual  ...                NaN              Q4 2017      False
# 73   Individual  ...                NaN              Q4 2017      False
# 175  Individual  ...                NaN              Q4 2017      False
# 204  Individual  ...                NaN              Q4 2017      False
# 239  Individual  ...                NaN              Q4 2017      False
# 18   Individual  ...                NaN              Q4 2017      False
# 115  Individual  ...                NaN              Q4 2017       True
#
#     IsAggregation RegulatedEntityId  AccountingUnitId  DonorId  \
# 291         False                52            1253.0    83880
# 83           True                90            2124.0    45282
# 113          True                53               NaN    37535
# 81          False               102            2602.0    45126
# 73           True                90            2364.0    83337
# 175         False                90            2125.0    83349
# 204          True                90               NaN    54432
# 239         False                52            1633.0    34251
# 18          False                90               NaN    34534
# 115         False                90               NaN    83339
#
#     CampaigningName   RegisterName  IsIrishSource
# 291             NaN  Great Britain          False
# 83              NaN  Great Britain          False
# 113             NaN  Great Britain          False
# 81              NaN  Great Britain          False
# 73              NaN  Great Britain          False
# 175             NaN  Great Britain          False
# 204             NaN  Great Britain          False
# 239             NaN  Great Britain          False
# 18              NaN  Great Britain          False
# 115             NaN  Great Britain          False
#
# [10 rows x 29 columns]

# %% [markdown]
# Use `df.tail(10)` to look at the last ten rows of the data:

# %%
df.tail(10)
# Out:
#          ECRef              RegulatedEntityName RegulatedEntityType  \
# 290  NC0364001     UK Independence Party (UKIP)     Political Party
# 291   C0376428  Conservative and Unionist Party     Political Party
# 292   C0363992     UK Independence Party (UKIP)     Political Party
# 293   C0364019     UK Independence Party (UKIP)     Political Party
# 294   C0363993     UK Independence Party (UKIP)     Political Party
# 295   C0363988     UK Independence Party (UKIP)     Political Party
# 296   C0364018     UK Independence Party (UKIP)     Political Party
# 297   C0364007     UK Independence Party (UKIP)     Political Party
# 298   C0363987     UK Independence Party (UKIP)     Political Party
# 299   C0393892                     Labour Party     Political Party
#
#          Value AcceptedDate        AccountingUnitName  \
# 290    £650.00   31/03/2017   Harwich and North Essex
# 291  £2,500.00   27/03/2017                    Havant
# 292  £2,500.00   15/02/2017             Central Party
# 293  £1,000.00   08/02/2017             Central Party
# 294  £5,000.00   26/01/2017             Central Party
# 295  £1,000.00   26/01/2017             Central Party
# 296  £5,000.00   26/01/2017             Central Party
# 297  £1,000.00   13/01/2017             Central Party
# 298  £1,000.00   12/01/2017             Central Party
# 299  £1,000.00   10/01/2017  Folkestone and Hythe CLP
#
#                      DonorName  AccountingUnitsAsCentralParty  IsSponsorship  \
# 290        Mr Duncan Greenland                          False          False
# 291             Mr Jeremy Hand                          False          False
# 292      Professor Tim Congdon                          False          False
# 293  Lord D Stevens of Ludgate                          False          False
# 294      Professor Tim Congdon                          False          False
# 295        Mr Duncan Greenland                          False          False
# 296  Lord D Stevens of Ludgate                          False          False
# 297        Mr Duncan Greenland                          False          False
# 298         Mr Malcolm Bluemel                          False          False
# 299        Mr Duncan Greenland                           True          False
#
#     DonorStatus  ...  IsReportedPrePoll  ReportingPeriodName  IsBequest  \
# 290  Individual  ...                NaN              Q4 2017      False
# 291  Individual  ...                NaN              Q4 2017      False
# 292  Individual  ...                NaN              Q4 2017      False
# 293  Individual  ...                NaN              Q4 2017      False
# 294  Individual  ...                NaN              Q4 2017      False
# 295  Individual  ...                NaN              Q4 2017      False
# 296  Individual  ...                NaN              Q4 2017      False
# 297  Individual  ...                NaN              Q4 2017      False
# 298  Individual  ...                NaN              Q4 2017      False
# 299  Individual  ...                NaN              Q4 2017      False
#
#     IsAggregation RegulatedEntityId  AccountingUnitId  DonorId  \
# 290          True                85            4914.0    83324
# 291         False                52            1253.0    83880
# 292          True                85               NaN    38170
# 293          True                85               NaN    48879
# 294          True                85               NaN    38170
# 295          True                85               NaN    83323
# 296          True                85               NaN    48879
# 297          True                85               NaN    74686
# 298          True                85               NaN    83323
# 299          True                53             295.0    83996
#
#     CampaigningName   RegisterName  IsIrishSource
# 290             NaN  Great Britain          False
# 291             NaN  Great Britain          False
# 292             NaN  Great Britain          False
# 293             NaN  Great Britain          False
# 294             NaN  Great Britain          False
# 295             NaN  Great Britain          False
# 296             NaN  Great Britain          False
# 297             NaN  Great Britain          False
# 298             NaN  Great Britain          False
# 299             NaN  Great Britain          False
#
# [10 rows x 29 columns]

# %% [markdown]
# To look at a random sample of the data set, typ `df.sample(5)`.

# %%
df.sample(5)
# Out:
#         ECRef              RegulatedEntityName RegulatedEntityType  \
# 94   C0364260                Liberal Democrats     Political Party
# 270  C0376399  Conservative and Unionist Party     Political Party
# 170  C0363985             Scottish Green Party     Political Party
# 172  C0363983             Scottish Green Party     Political Party
# 218  C0376275  Conservative and Unionist Party     Political Party
#
#           Value AcceptedDate AccountingUnitName                    DonorName  \
# 94    £1,846.00   31/12/2017         Cheltenham           Mr Andrew Mckinlay
# 270   £4,000.00   24/06/2017           Stafford         Mr Elizabeth A Gooch
# 170   £7,805.16   01/12/2017      Central Party  Mr Mark Christopher Ruskell
# 172   £7,846.32   01/12/2017      Central Party      Mr John Bradford Finnie
# 218  £10,000.00   03/11/2017      Central Party          Mr Neville A Baxter
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  ...  \
# 94                           False          False  Individual  ...
# 270                          False          False  Individual  ...
# 170                          False          False  Individual  ...
# 172                          False          False  Individual  ...
# 218                          False          False  Individual  ...
#
#      IsReportedPrePoll  ReportingPeriodName  IsBequest IsAggregation  \
# 94                 NaN              Q4 2017      False          True
# 270                NaN              Q4 2017      False         False
# 170                NaN              Q4 2017      False          True
# 172                NaN              Q4 2017      False          True
# 218                NaN              Q4 2017      False         False
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 94                 90            1873.0    48691             NaN
# 270                52            1606.0    47085             NaN
# 170               130               NaN    83321             NaN
# 172               130               NaN    83320             NaN
# 218                52               NaN    34323             NaN
#
#       RegisterName  IsIrishSource
# 94   Great Britain          False
# 270  Great Britain          False
# 170  Great Britain          False
# 172  Great Britain          False
# 218  Great Britain          False
#
# [5 rows x 29 columns]

# %% [markdown]
# Next we want to know what data types we're dealing with for each column in our dataframe
#
# Within Python different types of information, have different names. Using `df.dtypes` you can see what data type is in each column of the dataframe.
#
# **Most common data types**
# * **int**: short for integer, a number with no decimal
# * **float**: short for floating point, a number with at least one decimal.
# * **string**: usually a bit of text, if there are numbers in a string they are not recognized as such. Python will see a string as text.
# * **object**: usually a bit of text, if there are numbers in a string they are not recognized as such. Python will see a string as text.
# * **bool**: short for boolean, a binary data type, (true/false)

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                  float64
# RegisterName                      object
# IsIrishSource                       bool
# dtype: object

# %% [markdown]
# To see the shape of the dataframe - the number of rows and columns - type `df.shape`.

# %%
df.shape
# Out:
# (300, 29)

# %% [markdown]
# To see a descriptive statistics summary of our data, including the median, average value for every column, type `df.describe()`

# %%
database.describe()
# Out:
#        RegulatedDoneeType  CompanyRegistrationNumber  Postcode  \
# count                 0.0                        0.0       0.0
# mean                  NaN                        NaN       NaN
# std                   NaN                        NaN       NaN
# min                   NaN                        NaN       NaN
# 25%                   NaN                        NaN       NaN
# 50%                   NaN                        NaN       NaN
# 75%                   NaN                        NaN       NaN
# max                   NaN                        NaN       NaN
#
#        PurposeOfVisit  DonationAction  IsReportedPrePoll  RegulatedEntityId  \
# count             0.0             0.0                0.0         300.000000
# mean              NaN             NaN                NaN         138.116667
# std               NaN             NaN                NaN         596.037318
# min               NaN             NaN                NaN          52.000000
# 25%               NaN             NaN                NaN          52.000000
# 50%               NaN             NaN                NaN          85.000000
# 75%               NaN             NaN                NaN          90.000000
# max               NaN             NaN                NaN        6595.000000
#
#        AccountingUnitId       DonorId  CampaigningName
# count        171.000000    300.000000              0.0
# mean        2315.818713  65556.336667              NaN
# std         1281.242130  19466.692599              NaN
# min           38.000000  19152.000000              NaN
# 25%         1512.000000  47058.000000              NaN
# 50%         2013.000000  76334.000000              NaN
# 75%         2386.000000  83335.500000              NaN
# max         5278.000000  84031.000000              NaN

# %% [markdown]
# As you can see, using `df.describe()`, the Value column is missing. What happened? The most interesting data is in there... Well, remember when we asked Python to give us the data type for each column using `df.dtypes`?
#
# Turns out, Python doesn't recognize the values in the Value column as numbers. Spoiler alert: that might have something to do with the comma's and pound-sign in that column. Guess what? It's time to do some data cleaning.
#
# # Clean data
#
# **Clean data to do list**
# - make sure that numerical values are recognized as such
# - dates are just objects, lets make Python recognize dates as dates
# - create new columns based on the date (like a column for year and month)

# %% [markdown]
# ## Cleaning strings
#
# If we're going to analyse the data, we need the Value column to be recognized as float-numbers. (Floats, not ints since the Value column has numbers with decimals in there.)
#
# First, let's remove all of the pound-signs £... Type `df['ValueClean'] = df['Value'].str.replace('£', '')`. Now, what does this doe? It adds the column ValueClean, which is exactly the same as the column Value, but with every '£' replaced by nothing.

# %%
df["ValueClean"] = df["Value"].str.replace("£", "")

# %%
df.head(10)
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType       Value  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party  £20,000.00
# 1  C0364233                 Liberal Democrats     Political Party   £1,800.00
# 2  C0364187                 Liberal Democrats     Political Party   £3,000.00
# 3  C0364207                 Liberal Democrats     Political Party   £1,560.00
# 4  C0364113                 Liberal Democrats     Political Party   £7,750.00
# 5  C0364156                 Liberal Democrats     Political Party   £1,800.00
# 6  C0364219                 Liberal Democrats     Political Party   £1,838.00
# 7  C0364238                 Liberal Democrats     Political Party   £1,779.00
# 8  C0364264                 Liberal Democrats     Political Party   £2,400.00
# 9  C0364101                 Liberal Democrats     Political Party   £1,560.00
#
#   AcceptedDate                AccountingUnitName                   DonorName  \
# 0   19/12/2018                     Central Party       Mr Alun Ffred Jones
# 1   31/12/2017                   Greater Reading            Ms Kirsten Bayes
# 2   31/12/2017             South Gloucestershire              Mr Steve  Webb
# 3   31/12/2017          Westmorland and Lonsdale               Mr Tim Farron
# 4   31/12/2017                     Central Party         Mr Duncan Greenland
# 5   31/12/2017                       Hazel Grove             Mr Michael Lees
# 6   31/12/2017                        Cheltenham          Ms Jane Mactaggart
# 7   31/12/2017                        Gloucester            Mr Jeremy Hilton
# 8   31/12/2017  Parliamentary Party In The Lords  Baroness Kathryn Parminter
# 9   31/12/2017                            Yeovil     Lady Catherine Bakewell
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  ...  \
# 0                          False          False  Individual  ...
# 1                          False          False  Individual  ...
# 2                          False          False  Individual  ...
# 3                          False          False  Individual  ...
# 4                           True          False  Individual  ...
# 5                          False          False  Individual  ...
# 6                          False          False  Individual  ...
# 7                          False          False  Individual  ...
# 8                          False          False  Individual  ...
# 9                          False          False  Individual  ...
#
#    ReportingPeriodName  IsBequest  IsAggregation RegulatedEntityId  \
# 0              Q4 2017      False           True                77
# 1              Q4 2017      False           True                90
# 2              Q4 2017      False           True                90
# 3              Q4 2017      False           True                90
# 4              Q4 2017      False           True                90
# 5              Q4 2017      False           True                90
# 6              Q4 2017      False           True                90
# 7              Q4 2017      False           True                90
# 8              Q4 2017      False           True                90
# 9              Q4 2017      False           True                90
#
#   AccountingUnitId  DonorId  CampaigningName   RegisterName IsIrishSource  \
# 0              NaN    83318              NaN  Great Britain         False
# 1           1998.0    43033              NaN  Great Britain         False
# 2           5141.0    35400              NaN  Great Britain         False
# 3           2386.0    76661              NaN  Great Britain         False
# 4              NaN    35403              NaN  Great Britain         False
# 5           2022.0    76645              NaN  Great Britain         False
# 6           1873.0    47793              NaN  Great Britain         False
# 7           1991.0    83347              NaN  Great Britain         False
# 8           4578.0    37433              NaN  Great Britain         False
# 9           2414.0    50620              NaN  Great Britain         False
#
#    ValueClean
# 0   20,000.00
# 1    1,800.00
# 2    3,000.00
# 3    1,560.00
# 4    7,750.00
# 5    1,800.00
# 6    1,838.00
# 7    1,779.00
# 8    2,400.00
# 9    1,560.00
#
# [10 rows x 30 columns]

# %% [markdown]
# Let's heave a look at the first rows to see how we've done. Remember `df.head()`? ValueClean will be added at the right end of the table...

# %% [markdown]
# We're not done yet with this ValueClean column. We need to remove all comma's - Python doesn't like comma's or points for thousands, only for decimals. How would you remove all comma's in the ValueClean column without creating a new column?
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
# The answer looks a lot like `df['ValueClean'] = df['Value'].str.replace('£', '')` but isn't exactly the same...
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
# Type `df['ValueClean'] = df['ValueClean'].str.replace(',', '')`, which will replace the column ValueClean with the column ValueClean where all comma's are replaced by nothing.

# %%
df['ValueClean'] = df['ValueClean'].str.replace(",", "")

# %%
df
# Out:
#         ECRef               RegulatedEntityName RegulatedEntityType  \
# 0    C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1    C0364233                 Liberal Democrats     Political Party
# 2    C0364187                 Liberal Democrats     Political Party
# 3    C0364207                 Liberal Democrats     Political Party
# 4    C0364113                 Liberal Democrats     Political Party
# ..        ...                               ...                 ...
# 295  C0363988      UK Independence Party (UKIP)     Political Party
# 296  C0364018      UK Independence Party (UKIP)     Political Party
# 297  C0364007      UK Independence Party (UKIP)     Political Party
# 298  C0363987      UK Independence Party (UKIP)     Political Party
# 299  C0393892                      Labour Party     Political Party
#
#           Value AcceptedDate        AccountingUnitName  \
# 0    £20,000.00   19/12/2018             Central Party
# 1     £1,800.00   31/12/2017           Greater Reading
# 2     £3,000.00   31/12/2017     South Gloucestershire
# 3     £1,560.00   31/12/2017  Westmorland and Lonsdale
# 4     £7,750.00   31/12/2017             Central Party
# ..          ...          ...                       ...
# 295   £1,000.00   26/01/2017             Central Party
# 296   £5,000.00   26/01/2017             Central Party
# 297   £1,000.00   13/01/2017             Central Party
# 298   £1,000.00   12/01/2017             Central Party
# 299   £1,000.00   10/01/2017  Folkestone and Hythe CLP
#
#                      DonorName  AccountingUnitsAsCentralParty  IsSponsorship  \
# 0        Mr Alun Ffred Jones                            False          False
# 1             Ms Kirsten Bayes                          False          False
# 2               Mr Steve  Webb                          False          False
# 3                Mr Tim Farron                          False          False
# 4          Mr Duncan Greenland                           True          False
# ..                         ...                            ...            ...
# 295        Mr Duncan Greenland                          False          False
# 296  Lord D Stevens of Ludgate                          False          False
# 297        Mr Duncan Greenland                          False          False
# 298         Mr Malcolm Bluemel                          False          False
# 299        Mr Duncan Greenland                           True          False
#
#     DonorStatus  ...  ReportingPeriodName  IsBequest  IsAggregation  \
# 0    Individual  ...              Q4 2017      False           True
# 1    Individual  ...              Q4 2017      False           True
# 2    Individual  ...              Q4 2017      False           True
# 3    Individual  ...              Q4 2017      False           True
# 4    Individual  ...              Q4 2017      False           True
# ..          ...  ...                  ...        ...            ...
# 295  Individual  ...              Q4 2017      False           True
# 296  Individual  ...              Q4 2017      False           True
# 297  Individual  ...              Q4 2017      False           True
# 298  Individual  ...              Q4 2017      False           True
# 299  Individual  ...              Q4 2017      False           True
#
#     RegulatedEntityId AccountingUnitId  DonorId  CampaigningName  \
# 0                  77              NaN    83318              NaN
# 1                  90           1998.0    43033              NaN
# 2                  90           5141.0    35400              NaN
# 3                  90           2386.0    76661              NaN
# 4                  90              NaN    35403              NaN
# ..                ...              ...      ...              ...
# 295                85              NaN    83323              NaN
# 296                85              NaN    48879              NaN
# 297                85              NaN    74686              NaN
# 298                85              NaN    83323              NaN
# 299                53            295.0    83996              NaN
#
#       RegisterName IsIrishSource  ValueClean
# 0    Great Britain         False    20000.00
# 1    Great Britain         False     1800.00
# 2    Great Britain         False     3000.00
# 3    Great Britain         False     1560.00
# 4    Great Britain         False     7750.00
# ..             ...           ...         ...
# 295  Great Britain         False     1000.00
# 296  Great Britain         False     5000.00
# 297  Great Britain         False     1000.00
# 298  Great Britain         False     1000.00
# 299  Great Britain         False     1000.00
#
# [300 rows x 30 columns]

# %% [markdown]
# Now, let's see if this did the trick. Use `df.dtypes` to see if the ValueClean column is now a float datatype...

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                  float64
# RegisterName                      object
# IsIrishSource                       bool
# ValueClean                        object
# dtype: object

# %% [markdown]
# Didn't work, huh? That's because we need to explicitly tell Python that the ValueClean column contains float numbers. We can use a Pandas function to do this - like all Pandas functions this one too starts with `pd.`:
#
# `df['ValueClean'] = pd.to_numeric(df['ValueClean'])`

# %%
df['ValueClean'] = pd.to_numeric(df['ValueClean'])

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                  float64
# RegisterName                      object
# IsIrishSource                       bool
# ValueClean                       float64
# dtype: object

# %% [markdown]
# ## Delete columns
#
# Ok, now we got our Value column cleaned up in ValueClean; we actually no longer need to keep the original Value column. In Pandas removing or deleting a column is called 'dropping a column'.
#
# Also good to know: in Pandas, rows (horizontal) in a dataframe have axis=0, columns (vertical) have the first axis (axis=1).
#
# Knowing this, typing `df = df.drop('Value', 1)` should make sense. It means: the dataframe is the dataframe with the column Value dropped.

# %%
df = df.drop('Value', 1)

# %%
df
# Out:
#         ECRef               RegulatedEntityName RegulatedEntityType  \
# 0    C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1    C0364233                 Liberal Democrats     Political Party
# 2    C0364187                 Liberal Democrats     Political Party
# 3    C0364207                 Liberal Democrats     Political Party
# 4    C0364113                 Liberal Democrats     Political Party
# ..        ...                               ...                 ...
# 295  C0363988      UK Independence Party (UKIP)     Political Party
# 296  C0364018      UK Independence Party (UKIP)     Political Party
# 297  C0364007      UK Independence Party (UKIP)     Political Party
# 298  C0363987      UK Independence Party (UKIP)     Political Party
# 299  C0393892                      Labour Party     Political Party
#
#     AcceptedDate        AccountingUnitName                  DonorName  \
# 0     19/12/2018             Central Party      Mr Alun Ffred Jones
# 1     31/12/2017           Greater Reading           Ms Kirsten Bayes
# 2     31/12/2017     South Gloucestershire             Mr Steve  Webb
# 3     31/12/2017  Westmorland and Lonsdale              Mr Tim Farron
# 4     31/12/2017             Central Party        Mr Duncan Greenland
# ..           ...                       ...                        ...
# 295   26/01/2017             Central Party        Mr Duncan Greenland
# 296   26/01/2017             Central Party  Lord D Stevens of Ludgate
# 297   13/01/2017             Central Party        Mr Duncan Greenland
# 298   12/01/2017             Central Party         Mr Malcolm Bluemel
# 299   10/01/2017  Folkestone and Hythe CLP        Mr Duncan Greenland
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 0                            False          False  Individual
# 1                            False          False  Individual
# 2                            False          False  Individual
# 3                            False          False  Individual
# 4                             True          False  Individual
# ..                             ...            ...         ...
# 295                          False          False  Individual
# 296                          False          False  Individual
# 297                          False          False  Individual
# 298                          False          False  Individual
# 299                           True          False  Individual
#
#      RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 0                   NaN  ...              Q4 2017      False          True
# 1                   NaN  ...              Q4 2017      False          True
# 2                   NaN  ...              Q4 2017      False          True
# 3                   NaN  ...              Q4 2017      False          True
# 4                   NaN  ...              Q4 2017      False          True
# ..                  ...  ...                  ...        ...           ...
# 295                 NaN  ...              Q4 2017      False          True
# 296                 NaN  ...              Q4 2017      False          True
# 297                 NaN  ...              Q4 2017      False          True
# 298                 NaN  ...              Q4 2017      False          True
# 299                 NaN  ...              Q4 2017      False          True
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 0                  77               NaN    83318             NaN
# 1                  90            1998.0    43033             NaN
# 2                  90            5141.0    35400             NaN
# 3                  90            2386.0    76661             NaN
# 4                  90               NaN    35403             NaN
# ..                ...               ...      ...             ...
# 295                85               NaN    83323             NaN
# 296                85               NaN    48879             NaN
# 297                85               NaN    74686             NaN
# 298                85               NaN    83323             NaN
# 299                53             295.0    83996             NaN
#
#       RegisterName  IsIrishSource ValueClean
# 0    Great Britain          False    20000.0
# 1    Great Britain          False     1800.0
# 2    Great Britain          False     3000.0
# 3    Great Britain          False     1560.0
# 4    Great Britain          False     7750.0
# ..             ...            ...        ...
# 295  Great Britain          False     1000.0
# 296  Great Britain          False     5000.0
# 297  Great Britain          False     1000.0
# 298  Great Britain          False     1000.0
# 299  Great Britain          False     1000.0
#
# [300 rows x 29 columns]

# %% [markdown]
# ## Renaming columns

# %% [markdown]
# With the Value column gone, we can rename ValueClean to Value. Use the following command to do this: `df = df.rename(columns={'old_name': 'new_name'})`

# %%
df = df.rename(columns = {"ValueClean" : "Value"})

# %% [markdown]
# ## Clean up column names
#
# Since leading and trail spaces will always come back to haunt you in your data analysis nightmares, you want to make sure you get them out of your way before analysing your data.
#
# Let's see if there are any of these spaces in our column names, by typing `df.columns`, which will give us a list of all column names.

# %%
df.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value'],
#       dtype='object')

# %% [markdown]
# Looking good to me... Let's check all donor names. Get a list of all donor names by using the following command: `df['columnname'].unique()`.

# %%
df['DonorName'].unique()
# Out:
# array(['Mr Alun Ffred Jones  ', 'Ms Kirsten Bayes', 'Mr Steve  Webb',
#        'Mr Tim Farron', 'Mr Duncan Greenland', 'Mr Michael Lees',
#        'Ms Jane Mactaggart', 'Mr Jeremy Hilton',
#        'Baroness Kathryn Parminter', 'Lady Catherine Bakewell',
#        'Mr Martin Elengorn', 'Cllr Ian Shires', 'Ms Liz  Morris',
#        'Dr Alun  Griffiths', 'Mr Dave  Hodgson', 'Mr David Goodwin',
#        'Mrs Elizabeth Barraclough', 'Baroness Shirley Williams',
#        'Lord Tim Clement-Jones', 'Mr Mark  Burch', 'Mr Arthur Hookway',
#        'Mr Brett Hammond', 'Mr Ashley Wood', 'Mrs Rowena Hay',
#        'Ms Lynne Featherstone', 'Ms Inga Lockington', 'Mr Peter Rothery',
#        'Mr Richard Keatinge', 'Mr Cliff Woodcraft', 'Mr Derek Eastman',
#        'Ms Gail  Engert', 'Mr Pathumal Ali', 'Mrs Klara Sudbury',
#        'Mr James Macpherson', 'Mr David Tutt', 'Mr Colin  Stears',
#        'Ms Mary Wane', 'Mr Alistair  Barr', 'Miss Jocelyn Clark',
#        ' Roger Michael Isherwood', 'Mr David E D Brownlow',
#        'Mr David E Brownlow', 'Cllr Joe Harris', 'Mr James Baker',
#        'Mr Dennis Meredith', 'Ms Anne  Winstanley', 'Mr David Brown',
#        'Mr Bernard Fisher', 'Mr A Serge Lourie',
#        'Mr Richard Christopher Breen', 'Mr Simon Wheeler',
#        'Mrs Mary-Jane Jeanes', 'Lord Richard Allan Of Hallam',
#        'Dr Robert Barr', 'Mrs Marian Radford', 'Baroness Barbara Janke',
#        'Mr M Joe Boyle', 'Mr Dominic Hiscock',
#        'Mr Manuel Abellan-San Martin', 'Ms Helen Clucas',
#        'Mr Edward Acland', 'Ms Joanna  Kenny', 'Mr Michael Carter',
#        'Ms Ruth  Dombey', 'Ms Karin Snowden', 'Mrs Sunita Gordon',
#        'Mr John Hale', 'Lord Paul  Strasburger', 'Mrs Carolyn Lambert',
#        'Mr Mark Watkin', 'Mr Andrew  Waller', 'Mr David  Beacham',
#        ' Christopher Williams', 'Mr John Mason', 'Mr Steven Lambert',
#        'Mrs Isobel McCall', 'Mr Michael Headley', 'Mr Robert Wood',
#        'Mr Mark  Petterson', 'Lord Nigel D Jones of Cheltenham',
#        'Mr Ian Cuthbertson', 'Mrs Marlene Heron', 'Mr Owen  Temple',
#        'Mr Edward Joyce', 'Mr SImon  Curtis', 'Mr Andrew Mckinlay',
#        'Ms Philippa  Connor', 'Mrs Hilary Stephenson', 'Mr Chris White',
#        'Mr Tom  Gosling', 'Mr Alan  Sherwell',
#        'Mr Gerald  Vernon-Jackson', 'Mr Keith Crout',
#        'Mr Alexey  Chudnovskiy', ' Stella Creasy', ' Mike Penning',
#        'Mr Anthony H Billingham', 'Mr Peter Wilson', 'Mrs Susan  Howes',
#        'Mr Greg  Dyke', 'Mr John B Rutter', 'Ms Christine E Dawood',
#        'Mr Alan  T Wicnh', 'Mr Stephen Kinsella', 'Mr David W Gray',
#        'Mr Robert Chicken', 'Mr Simon D Hume-Kendall',
#        'Ms Jennifer  Talbot', 'Sir Michael Hintze', 'Mr Jeremy J Lefroy',
#        'Mrs Gitte  Dawson', 'Mr Sam Singh', 'Mr Michael C Warshaw',
#        'Mr Edmund G Truell', 'Mr Surinderpal Lit', 'Mr Stephen S Less',
#        'Mr Stephen Howard', 'Lord Stanley Fink', 'Mr Dominic R Johnson',
#        'Mr Daniel P Hearsum', 'Baroness Emma Nicholson',
#        'Mr Nicholas Brougham', 'Dr Arujuna Sivananthan', 'Mr Mark J Page',
#        'Mr Michael Davis', 'Mr Michael J Wade', 'Mr Roger Manser',
#        'Mr Richard J Grimes', 'Mr Palminder Singh',
#        'Lord Charles Falconer of Thoroton', 'Professor Tim Congdon',
#        'Mr Arthur P Davidson', 'Mr Mohamed Mansour', 'Mr Peter Cruddas',
#        'Mr Alan C Bolton', 'Mr Ian McNish', 'Ms Jean Lambert MEP',
#        'Mr Ian Pirie', 'Mr Ian H Leslie-Melville', 'Mr Michael Slade',
#        'Lady Sarah L Keswick', 'Mr John D Lovering', 'Mr Dinesh Dhamija',
#        'Mr Andrew D Williams', 'Ms Alison Frost',
#        'Mr Raymond Chamberlain', 'Ms Elizabeth Reason',
#        'Mr Malcolm Bluemel', 'Mrs Catherine Pirie', 'Mr Andrew Law',
#        'Ms Alison Johnstone', 'Mr Simon M Haslam', 'Mr Patrick Harvie',
#        'Mr Ross John Greer', 'Lord John Crawford',
#        'Mr Mark Christopher Ruskell', 'Mr Andrew Dearg Wightman',
#        'Mr John Bradford Finnie', 'Mr Michael S Thronton OBE',
#        'Mr Henry Keswick', 'Mrs Hazel Watson', 'Mr Gerald H Elliot',
#        'Lord Paul Tyler', 'Mr Jeremy RS Hunt', 'Mr Edward  John Izzard',
#        'Lord D Stevens of Ludgate', 'Mr Michael Watson',
#        'Ms Marina Smethhurst', ' Clive Hollick', 'Mr Abdul-Majid Jafar',
#        'Mr Andrew  Godson', 'Mr Stephen P J Matthews',
#        'Mr Douglas Reynolds', 'Ms Nadezda Rodicheva', 'Ms Rania K Majeed',
#        'Mr Alexander Temerko', 'Mr Howard Leigh', 'Mr Thomas E Notman',
#        'Mrs Sarah J Pidgley', 'Mr Philip  L Wroughton',
#        'Mr Kenneth J French', 'Mr John Noel Penstone', 'Mrs Mary Erbrich',
#        'Mr Patrick D Horsfall', 'Mr Anthony  Harris',
#        'Mr Zac F Goldsmith', 'Mr Stephen  Dawson', 'Mr Peter Brown',
#        'Mr Tony Belton', 'Mr Jonathan Leslie Skeet', ' William  Goodhart',
#        'Mr Roger J Kendrick', 'Mr William Haughey', 'Ms Dora Bertolutti',
#        'Mr Neville A Baxter', 'Mr Oluwole Kolade', 'Mr Anthony Bunker',
#        'Mr Stephen L Massey', 'Hon George T Farmer',
#        'Mr Laurence Hollingworth', 'Ms Anna Gallop', 'Mr Vincent Cable',
#        'Mr John D Booth', 'Mrs Esme Forbes', 'Mr Iain Aitken',
#        'Mr Byron S Huson', 'Mr Navroz D Udwadia', 'Mr James R Lupton',
#        'Mr Ravi S Kailas', 'Mr Nicholas Campsie', 'Mr Nicholas N Moore',
#        'Mr William H Salomon', 'Mr Ian R Taylor', 'Lord Philip Harris',
#        ' Scirard Lancelyn Green', 'Mr Amjad Bseisu', 'Mr Gary Lydiate',
#        'Mr Roger G Orf', 'Ms Jane Turnell-Read', 'Ms Lesley Jackson',
#        'Mr Andrew Perloff', 'Mr Donald J Lewin', 'Mr Peter Kane',
#        'Mr Roger Nagioff', 'Mr Christopher M Higgins',
#        'Mr Michael A Dangoor', 'Mr Robert D Calrow', 'Mr Michael Cohen',
#        'Mr Arthur J Taylor', 'Mr David Charles Williams',
#        'Mr Robert J Madejski', 'Mr Andrew Pinnock',
#        'Lord John Lee Of Trafford', 'Ms Rachel H MacLean',
#        'Mr Elizabeth A Gooch', 'Mr Albert Mcintosh',
#        'Mr Jeremy J Hosking', 'Mr Neil Record', 'Mrs Menju Mehrotra',
#        'Mr Ravi Mehrotra', 'Mr Peter D Landale', 'Mr Daniel D Laycock',
#        'Mr Edward P Weatherall', "Mr John O'Hara",
#        'Mr Terence F Parkinson', 'Lord John Alderdice', 'Mr Jeremy Hand'],
#       dtype=object)

# %% [markdown]
# Well, well, well, Mr Alun Ffred Jones  !! It going to take multiple steps to fix that:
# 1. Let's make sure the DonorName column is a string.
# Use `df['columnname'] = df['columnname'].astype(str)`
# 2. Strip all strings in the column of leading and trail spaces.
# Use `df['columnname'] = df['columnname'].map(str.strip)`

# %%
df['DonorName'] = df['DonorName'].astype(str)
df['DonorName'] = df['DonorName'].map(str.strip)

# %% [markdown]
# Did that work? Let's see. `df['DonorName'].unique()`

# %%
df["DonorName"].unique()
# Out:
# array(['Mr Alun Ffred Jones', 'Ms Kirsten Bayes', 'Mr Steve  Webb',
#        'Mr Tim Farron', 'Mr Duncan Greenland', 'Mr Michael Lees',
#        'Ms Jane Mactaggart', 'Mr Jeremy Hilton',
#        'Baroness Kathryn Parminter', 'Lady Catherine Bakewell',
#        'Mr Martin Elengorn', 'Cllr Ian Shires', 'Ms Liz  Morris',
#        'Dr Alun  Griffiths', 'Mr Dave  Hodgson', 'Mr David Goodwin',
#        'Mrs Elizabeth Barraclough', 'Baroness Shirley Williams',
#        'Lord Tim Clement-Jones', 'Mr Mark  Burch', 'Mr Arthur Hookway',
#        'Mr Brett Hammond', 'Mr Ashley Wood', 'Mrs Rowena Hay',
#        'Ms Lynne Featherstone', 'Ms Inga Lockington', 'Mr Peter Rothery',
#        'Mr Richard Keatinge', 'Mr Cliff Woodcraft', 'Mr Derek Eastman',
#        'Ms Gail  Engert', 'Mr Pathumal Ali', 'Mrs Klara Sudbury',
#        'Mr James Macpherson', 'Mr David Tutt', 'Mr Colin  Stears',
#        'Ms Mary Wane', 'Mr Alistair  Barr', 'Miss Jocelyn Clark',
#        'Roger Michael Isherwood', 'Mr David E D Brownlow',
#        'Mr David E Brownlow', 'Cllr Joe Harris', 'Mr James Baker',
#        'Mr Dennis Meredith', 'Ms Anne  Winstanley', 'Mr David Brown',
#        'Mr Bernard Fisher', 'Mr A Serge Lourie',
#        'Mr Richard Christopher Breen', 'Mr Simon Wheeler',
#        'Mrs Mary-Jane Jeanes', 'Lord Richard Allan Of Hallam',
#        'Dr Robert Barr', 'Mrs Marian Radford', 'Baroness Barbara Janke',
#        'Mr M Joe Boyle', 'Mr Dominic Hiscock',
#        'Mr Manuel Abellan-San Martin', 'Ms Helen Clucas',
#        'Mr Edward Acland', 'Ms Joanna  Kenny', 'Mr Michael Carter',
#        'Ms Ruth  Dombey', 'Ms Karin Snowden', 'Mrs Sunita Gordon',
#        'Mr John Hale', 'Lord Paul  Strasburger', 'Mrs Carolyn Lambert',
#        'Mr Mark Watkin', 'Mr Andrew  Waller', 'Mr David  Beacham',
#        'Christopher Williams', 'Mr John Mason', 'Mr Steven Lambert',
#        'Mrs Isobel McCall', 'Mr Michael Headley', 'Mr Robert Wood',
#        'Mr Mark  Petterson', 'Lord Nigel D Jones of Cheltenham',
#        'Mr Ian Cuthbertson', 'Mrs Marlene Heron', 'Mr Owen  Temple',
#        'Mr Edward Joyce', 'Mr SImon  Curtis', 'Mr Andrew Mckinlay',
#        'Ms Philippa  Connor', 'Mrs Hilary Stephenson', 'Mr Chris White',
#        'Mr Tom  Gosling', 'Mr Alan  Sherwell',
#        'Mr Gerald  Vernon-Jackson', 'Mr Keith Crout',
#        'Mr Alexey  Chudnovskiy', 'Stella Creasy', 'Mike Penning',
#        'Mr Anthony H Billingham', 'Mr Peter Wilson', 'Mrs Susan  Howes',
#        'Mr Greg  Dyke', 'Mr John B Rutter', 'Ms Christine E Dawood',
#        'Mr Alan  T Wicnh', 'Mr Stephen Kinsella', 'Mr David W Gray',
#        'Mr Robert Chicken', 'Mr Simon D Hume-Kendall',
#        'Ms Jennifer  Talbot', 'Sir Michael Hintze', 'Mr Jeremy J Lefroy',
#        'Mrs Gitte  Dawson', 'Mr Sam Singh', 'Mr Michael C Warshaw',
#        'Mr Edmund G Truell', 'Mr Surinderpal Lit', 'Mr Stephen S Less',
#        'Mr Stephen Howard', 'Lord Stanley Fink', 'Mr Dominic R Johnson',
#        'Mr Daniel P Hearsum', 'Baroness Emma Nicholson',
#        'Mr Nicholas Brougham', 'Dr Arujuna Sivananthan', 'Mr Mark J Page',
#        'Mr Michael Davis', 'Mr Michael J Wade', 'Mr Roger Manser',
#        'Mr Richard J Grimes', 'Mr Palminder Singh',
#        'Lord Charles Falconer of Thoroton', 'Professor Tim Congdon',
#        'Mr Arthur P Davidson', 'Mr Mohamed Mansour', 'Mr Peter Cruddas',
#        'Mr Alan C Bolton', 'Mr Ian McNish', 'Ms Jean Lambert MEP',
#        'Mr Ian Pirie', 'Mr Ian H Leslie-Melville', 'Mr Michael Slade',
#        'Lady Sarah L Keswick', 'Mr John D Lovering', 'Mr Dinesh Dhamija',
#        'Mr Andrew D Williams', 'Ms Alison Frost',
#        'Mr Raymond Chamberlain', 'Ms Elizabeth Reason',
#        'Mr Malcolm Bluemel', 'Mrs Catherine Pirie', 'Mr Andrew Law',
#        'Ms Alison Johnstone', 'Mr Simon M Haslam', 'Mr Patrick Harvie',
#        'Mr Ross John Greer', 'Lord John Crawford',
#        'Mr Mark Christopher Ruskell', 'Mr Andrew Dearg Wightman',
#        'Mr John Bradford Finnie', 'Mr Michael S Thronton OBE',
#        'Mr Henry Keswick', 'Mrs Hazel Watson', 'Mr Gerald H Elliot',
#        'Lord Paul Tyler', 'Mr Jeremy RS Hunt', 'Mr Edward  John Izzard',
#        'Lord D Stevens of Ludgate', 'Mr Michael Watson',
#        'Ms Marina Smethhurst', 'Clive Hollick', 'Mr Abdul-Majid Jafar',
#        'Mr Andrew  Godson', 'Mr Stephen P J Matthews',
#        'Mr Douglas Reynolds', 'Ms Nadezda Rodicheva', 'Ms Rania K Majeed',
#        'Mr Alexander Temerko', 'Mr Howard Leigh', 'Mr Thomas E Notman',
#        'Mrs Sarah J Pidgley', 'Mr Philip  L Wroughton',
#        'Mr Kenneth J French', 'Mr John Noel Penstone', 'Mrs Mary Erbrich',
#        'Mr Patrick D Horsfall', 'Mr Anthony  Harris',
#        'Mr Zac F Goldsmith', 'Mr Stephen  Dawson', 'Mr Peter Brown',
#        'Mr Tony Belton', 'Mr Jonathan Leslie Skeet', 'William  Goodhart',
#        'Mr Roger J Kendrick', 'Mr William Haughey', 'Ms Dora Bertolutti',
#        'Mr Neville A Baxter', 'Mr Oluwole Kolade', 'Mr Anthony Bunker',
#        'Mr Stephen L Massey', 'Hon George T Farmer',
#        'Mr Laurence Hollingworth', 'Ms Anna Gallop', 'Mr Vincent Cable',
#        'Mr John D Booth', 'Mrs Esme Forbes', 'Mr Iain Aitken',
#        'Mr Byron S Huson', 'Mr Navroz D Udwadia', 'Mr James R Lupton',
#        'Mr Ravi S Kailas', 'Mr Nicholas Campsie', 'Mr Nicholas N Moore',
#        'Mr William H Salomon', 'Mr Ian R Taylor', 'Lord Philip Harris',
#        'Scirard Lancelyn Green', 'Mr Amjad Bseisu', 'Mr Gary Lydiate',
#        'Mr Roger G Orf', 'Ms Jane Turnell-Read', 'Ms Lesley Jackson',
#        'Mr Andrew Perloff', 'Mr Donald J Lewin', 'Mr Peter Kane',
#        'Mr Roger Nagioff', 'Mr Christopher M Higgins',
#        'Mr Michael A Dangoor', 'Mr Robert D Calrow', 'Mr Michael Cohen',
#        'Mr Arthur J Taylor', 'Mr David Charles Williams',
#        'Mr Robert J Madejski', 'Mr Andrew Pinnock',
#        'Lord John Lee Of Trafford', 'Ms Rachel H MacLean',
#        'Mr Elizabeth A Gooch', 'Mr Albert Mcintosh',
#        'Mr Jeremy J Hosking', 'Mr Neil Record', 'Mrs Menju Mehrotra',
#        'Mr Ravi Mehrotra', 'Mr Peter D Landale', 'Mr Daniel D Laycock',
#        'Mr Edward P Weatherall', "Mr John O'Hara",
#        'Mr Terence F Parkinson', 'Lord John Alderdice', 'Mr Jeremy Hand'],
#       dtype=object)

# %% [markdown]
# ## Cleaning dates
#
# Ok, so now we've only got to clean up our dates. We're going to use another python library: the datetime library contains some neat and handy datetime tools. Just what we need, type: `import datetime`

# %%
import datetime

# %% [markdown]
# Let's have another look at some of our data before we start working on the date column. Use `df.head()`, `df.tail()` or my personal favorite `df.sample()`.

# %%
df.head()
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1  C0364233                 Liberal Democrats     Political Party
# 2  C0364187                 Liberal Democrats     Political Party
# 3  C0364207                 Liberal Democrats     Political Party
# 4  C0364113                 Liberal Democrats     Political Party
#
#   AcceptedDate        AccountingUnitName            DonorName  \
# 0   19/12/2018             Central Party  Mr Alun Ffred Jones
# 1   31/12/2017           Greater Reading     Ms Kirsten Bayes
# 2   31/12/2017     South Gloucestershire       Mr Steve  Webb
# 3   31/12/2017  Westmorland and Lonsdale        Mr Tim Farron
# 4   31/12/2017             Central Party  Mr Duncan Greenland
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 0                          False          False  Individual
# 1                          False          False  Individual
# 2                          False          False  Individual
# 3                          False          False  Individual
# 4                           True          False  Individual
#
#    RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 0                 NaN  ...              Q4 2017      False          True
# 1                 NaN  ...              Q4 2017      False          True
# 2                 NaN  ...              Q4 2017      False          True
# 3                 NaN  ...              Q4 2017      False          True
# 4                 NaN  ...              Q4 2017      False          True
#
#   RegulatedEntityId  AccountingUnitId  DonorId CampaigningName   RegisterName  \
# 0                77               NaN    83318             NaN  Great Britain
# 1                90            1998.0    43033             NaN  Great Britain
# 2                90            5141.0    35400             NaN  Great Britain
# 3                90            2386.0    76661             NaN  Great Britain
# 4                90               NaN    35403             NaN  Great Britain
#
#    IsIrishSource    Value
# 0          False  20000.0
# 1          False   1800.0
# 2          False   3000.0
# 3          False   1560.0
# 4          False   7750.0
#
# [5 rows x 29 columns]

# %%
df.sample()
# Out:
#         ECRef              RegulatedEntityName RegulatedEntityType  \
# 206  C0376237  Conservative and Unionist Party     Political Party
#
#     AcceptedDate   AccountingUnitName           DonorName  \
# 206   15/11/2017  Chatham & Aylesford  Mr Zac F Goldsmith
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 206                          False          False  Individual
#
#      RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 206                 NaN  ...              Q4 2017      False         False
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 206                52            1049.0    69726             NaN
#
#       RegisterName  IsIrishSource   Value
# 206  Great Britain          False  5000.0
#
# [1 rows x 29 columns]

# %% [markdown]
# Our dates are in the AcceptedDate column. Let's make sure these dates are recognized as such. Use `df['AcceptedDate'] = pd.to_datetime(df['AcceptedDate'], format="%d/%m/%Y")` to change the data type from object to date. Use `df.head()`, `df.tail()` or `df.sample()` to see if it worked.

# %%
df['AcceptedDate'] = pd.to_datetime(df['AcceptedDate'], format = "%d/%m/%Y")

# %% [markdown]
# Now, did the data type of the AcceptedDate column change? Use `df.dtypes` to check.

# %%
df.head()
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1  C0364233                 Liberal Democrats     Political Party
# 2  C0364187                 Liberal Democrats     Political Party
# 3  C0364207                 Liberal Democrats     Political Party
# 4  C0364113                 Liberal Democrats     Political Party
#
#   AcceptedDate        AccountingUnitName            DonorName  \
# 0   2018-12-19             Central Party  Mr Alun Ffred Jones
# 1   2017-12-31           Greater Reading     Ms Kirsten Bayes
# 2   2017-12-31     South Gloucestershire       Mr Steve  Webb
# 3   2017-12-31  Westmorland and Lonsdale        Mr Tim Farron
# 4   2017-12-31             Central Party  Mr Duncan Greenland
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 0                          False          False  Individual
# 1                          False          False  Individual
# 2                          False          False  Individual
# 3                          False          False  Individual
# 4                           True          False  Individual
#
#    RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 0                 NaN  ...              Q4 2017      False          True
# 1                 NaN  ...              Q4 2017      False          True
# 2                 NaN  ...              Q4 2017      False          True
# 3                 NaN  ...              Q4 2017      False          True
# 4                 NaN  ...              Q4 2017      False          True
#
#   RegulatedEntityId  AccountingUnitId  DonorId CampaigningName   RegisterName  \
# 0                77               NaN    83318             NaN  Great Britain
# 1                90            1998.0    43033             NaN  Great Britain
# 2                90            5141.0    35400             NaN  Great Britain
# 3                90            2386.0    76661             NaN  Great Britain
# 4                90               NaN    35403             NaN  Great Britain
#
#    IsIrishSource    Value
# 0          False  20000.0
# 1          False   1800.0
# 2          False   3000.0
# 3          False   1560.0
# 4          False   7750.0
#
# [5 rows x 29 columns]

# %%
df.dtypes
# Out:
# ECRef                                    object
# RegulatedEntityName                      object
# RegulatedEntityType                      object
# AcceptedDate                     datetime64[ns]
# AccountingUnitName                       object
# DonorName                                object
# AccountingUnitsAsCentralParty              bool
# IsSponsorship                              bool
# DonorStatus                              object
# RegulatedDoneeType                      float64
# CompanyRegistrationNumber               float64
# Postcode                                float64
# DonationType                             object
# NatureOfDonation                         object
# PurposeOfVisit                          float64
# DonationAction                          float64
# ReceivedDate                             object
# ReportedDate                             object
# IsReportedPrePoll                       float64
# ReportingPeriodName                      object
# IsBequest                                  bool
# IsAggregation                              bool
# RegulatedEntityId                         int64
# AccountingUnitId                        float64
# DonorId                                   int64
# CampaigningName                         float64
# RegisterName                             object
# IsIrishSource                              bool
# Value                                   float64
# dtype: object

# %% [markdown]
# Worked perfectly! :)
#
# ## Adding columns with year and month
#
# Now, let's create two new columns. One with the month and one with the years... Since Python now knows that the AcceptedDate column contains dates, we can use out-of-the-box functions from pandas and the datetime libraries.
#
# Creating a column with the years based on the AcceptedDate column, becomes as easy as `df['Year'] = pd.DatetimeIndex(df['AcceptedDate']).year`.

# %%
df['Year'] = pd.DatetimeIndex(df['AcceptedDate']).year

# %%
df.head(10)
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1  C0364233                 Liberal Democrats     Political Party
# 2  C0364187                 Liberal Democrats     Political Party
# 3  C0364207                 Liberal Democrats     Political Party
# 4  C0364113                 Liberal Democrats     Political Party
# 5  C0364156                 Liberal Democrats     Political Party
# 6  C0364219                 Liberal Democrats     Political Party
# 7  C0364238                 Liberal Democrats     Political Party
# 8  C0364264                 Liberal Democrats     Political Party
# 9  C0364101                 Liberal Democrats     Political Party
#
#   AcceptedDate                AccountingUnitName                   DonorName  \
# 0   2018-12-19                     Central Party         Mr Alun Ffred Jones
# 1   2017-12-31                   Greater Reading            Ms Kirsten Bayes
# 2   2017-12-31             South Gloucestershire              Mr Steve  Webb
# 3   2017-12-31          Westmorland and Lonsdale               Mr Tim Farron
# 4   2017-12-31                     Central Party         Mr Duncan Greenland
# 5   2017-12-31                       Hazel Grove             Mr Michael Lees
# 6   2017-12-31                        Cheltenham          Ms Jane Mactaggart
# 7   2017-12-31                        Gloucester            Mr Jeremy Hilton
# 8   2017-12-31  Parliamentary Party In The Lords  Baroness Kathryn Parminter
# 9   2017-12-31                            Yeovil     Lady Catherine Bakewell
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 0                          False          False  Individual
# 1                          False          False  Individual
# 2                          False          False  Individual
# 3                          False          False  Individual
# 4                           True          False  Individual
# 5                          False          False  Individual
# 6                          False          False  Individual
# 7                          False          False  Individual
# 8                          False          False  Individual
# 9                          False          False  Individual
#
#    RegulatedDoneeType  ...  IsBequest  IsAggregation RegulatedEntityId  \
# 0                 NaN  ...      False           True                77
# 1                 NaN  ...      False           True                90
# 2                 NaN  ...      False           True                90
# 3                 NaN  ...      False           True                90
# 4                 NaN  ...      False           True                90
# 5                 NaN  ...      False           True                90
# 6                 NaN  ...      False           True                90
# 7                 NaN  ...      False           True                90
# 8                 NaN  ...      False           True                90
# 9                 NaN  ...      False           True                90
#
#   AccountingUnitId  DonorId  CampaigningName   RegisterName IsIrishSource  \
# 0              NaN    83318              NaN  Great Britain         False
# 1           1998.0    43033              NaN  Great Britain         False
# 2           5141.0    35400              NaN  Great Britain         False
# 3           2386.0    76661              NaN  Great Britain         False
# 4              NaN    35403              NaN  Great Britain         False
# 5           2022.0    76645              NaN  Great Britain         False
# 6           1873.0    47793              NaN  Great Britain         False
# 7           1991.0    83347              NaN  Great Britain         False
# 8           4578.0    37433              NaN  Great Britain         False
# 9           2414.0    50620              NaN  Great Britain         False
#
#      Value  Year
# 0  20000.0  2018
# 1   1800.0  2017
# 2   3000.0  2017
# 3   1560.0  2017
# 4   7750.0  2017
# 5   1800.0  2017
# 6   1838.0  2017
# 7   1779.0  2017
# 8   2400.0  2017
# 9   1560.0  2017
#
# [10 rows x 30 columns]

# %% [markdown]
# Use `df.head()`, `df.tail()` or `df.sample()` to see if it worked. Our new column will be added on the right side of the dataframe.

# %%
df.sample()
# Out:
#        ECRef RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 47  C0364089   Liberal Democrats     Political Party   2017-12-31
#
#    AccountingUnitName            DonorName  AccountingUnitsAsCentralParty  \
# 47          Eastleigh  Ms Anne  Winstanley                          False
#
#     IsSponsorship DonorStatus  RegulatedDoneeType  ...  IsBequest  \
# 47          False  Individual                 NaN  ...      False
#
#     IsAggregation RegulatedEntityId AccountingUnitId  DonorId  \
# 47          False                90           1947.0    34181
#
#     CampaigningName   RegisterName IsIrishSource   Value  Year
# 47              NaN  Great Britain         False  2000.0  2017
#
# [1 rows x 30 columns]

# %% [markdown]
# To add a column with all months is just as easy. `df['Month'] = pd.DatetimeIndex(df['AcceptedDate']).month` will do the trick, it means: in the dataframe called 'df', create a new column called 'Month' and fill it with months, which you should base on the date inside the column AcceptedDate of the dataframe df.

# %%
df['Month'] = pd.DatetimeIndex(df['AcceptedDate']).month

# %% [markdown]
# Use `df.head()`, `df.tail()` or `df.sample()` to see if it worked. For something like this, i like to use the `df.sample()` function; it allows you to see if it worked with different values.
#
# Off course this new column too is  added on the right side of the dataframe.

# %%
df.sample()
# Out:
#        ECRef RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 76  C0364228   Liberal Democrats     Political Party   2017-12-31
#
#    AccountingUnitName       DonorName  AccountingUnitsAsCentralParty  \
# 76            Watford  Mr Mark Watkin                          False
#
#     IsSponsorship DonorStatus  RegulatedDoneeType  ...  IsAggregation  \
# 76          False  Individual                 NaN  ...           True
#
#     RegulatedEntityId AccountingUnitId DonorId  CampaigningName  \
# 76                 90           2364.0   48732              NaN
#
#      RegisterName IsIrishSource   Value  Year Month
# 76  Great Britain         False  1800.0  2017    12
#
# [1 rows x 31 columns]

# %% [markdown]
# # Removing columns
#
# Our dataframe is quite big. Maybe we can remove some columns? Let's see how many columns we got... Use `df.columns` and `df.shape` to familiarize yourself with the number of columns and their names.

# %%
df.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value', 'Year',
#        'Month'],
#       dtype='object')

# %%
df.shape
# Out:
# (300, 31)

# %% [markdown]
# Let's get rid of the columns 'ECRef', 'AccountingUnitName', 'AccountingUnitsAsCentralParty', 'IsSponsorship', 'RegulatedDoneeType', 'CompanyRegistrationNumber', 'Postcode', 'DonationType','NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate', 'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest', 'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'RegisterName', 'IsIrishSource', 'AcceptedDateClean'.
#
# Let's drop some columns! `df = df.drop('Value', 1)`
#
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
# Or, maybe we should just tell the computer what columns we like to keep. Might be shorter. :)
# Use `dfMini = df[['RegulatedEntityName', 'AcceptedDate', 'DonorName', 'DonorStatus', 'Year', 'Month','Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]`

# %%
dfMini = df[['RegulatedEntityName', 'AcceptedDate', 'DonorName', 'DonorStatus', 'Year', 'Month','Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]

# %%
dfMini
# Out:
#                   RegulatedEntityName AcceptedDate                  DonorName  \
# 0    Plaid Cymru - The Party of Wales   2018-12-19        Mr Alun Ffred Jones
# 1                   Liberal Democrats   2017-12-31           Ms Kirsten Bayes
# 2                   Liberal Democrats   2017-12-31             Mr Steve  Webb
# 3                   Liberal Democrats   2017-12-31              Mr Tim Farron
# 4                   Liberal Democrats   2017-12-31        Mr Duncan Greenland
# ..                                ...          ...                        ...
# 295      UK Independence Party (UKIP)   2017-01-26        Mr Duncan Greenland
# 296      UK Independence Party (UKIP)   2017-01-26  Lord D Stevens of Ludgate
# 297      UK Independence Party (UKIP)   2017-01-13        Mr Duncan Greenland
# 298      UK Independence Party (UKIP)   2017-01-12         Mr Malcolm Bluemel
# 299                      Labour Party   2017-01-10        Mr Duncan Greenland
#
#     DonorStatus  Year  Month    Value RegulatedEntityType  DonorId  \
# 0    Individual  2018     12  20000.0     Political Party    83318
# 1    Individual  2017     12   1800.0     Political Party    43033
# 2    Individual  2017     12   3000.0     Political Party    35400
# 3    Individual  2017     12   1560.0     Political Party    76661
# 4    Individual  2017     12   7750.0     Political Party    35403
# ..          ...   ...    ...      ...                 ...      ...
# 295  Individual  2017      1   1000.0     Political Party    83323
# 296  Individual  2017      1   5000.0     Political Party    48879
# 297  Individual  2017      1   1000.0     Political Party    74686
# 298  Individual  2017      1   1000.0     Political Party    83323
# 299  Individual  2017      1   1000.0     Political Party    83996
#
#      CampaigningName
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 295              NaN
# 296              NaN
# 297              NaN
# 298              NaN
# 299              NaN
#
# [300 rows x 10 columns]

# %% [markdown]
# ## Save your data
#
# Now that we've put all this work into cleaning our dataset, let's save a copy. Off course Pandas has a nifty command for that too. Use `dfMini.to_csv('filename.csv', encoding='utf8')`.
#
# Be ware: use a different name than the filename of the original data file, or it will be overwritten.

# %%
dfMini.to_csv('resultscleanQ42017.csv', encoding = 'utf8')

# %% [markdown]
# In case you want to check if a new file was created in your directory, you can use the `pwd` and `ls` commands. At the beginning of this module, we used these commands to print the working directory (`pwd`) and list the content of the working directory (`ls`).
#
# First, use `pwd` to see in which folder - also known as directory - you are:

# %%
pwd
# Out:
# 'C:\\Users\\u0168991\\Documents\\pythonforjournalists\\Clean Data'

# %% [markdown]
# Now use `ls` to get a list of all files in this directory. If everything worked your newly saved datafile should be among the files in the list.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is AA9C-2383
#
#  Directory of C:\Users\u0168991\Documents\pythonforjournalists\Clean Data
#
# 04/20/2020  12:28 PM    <DIR>          .
# 04/20/2020  12:28 PM    <DIR>          ..
# 04/20/2020  06:04 AM    <DIR>          .ipynb_checkpoints
# 04/20/2020  12:27 PM           199,425 Clean data v2.ipynb
# 04/20/2020  06:22 AM             7,742 pandas.ipynb
# 04/17/2020  05:03 AM            66,386 results.csv
# 04/20/2020  12:28 PM            32,581 resultscleanQ42017.csv
# 04/20/2020  10:13 AM             1,602 resultsQ42019.csv
#                5 File(s)        307,736 bytes
#                3 Dir(s)  161,444,806,656 bytes free
